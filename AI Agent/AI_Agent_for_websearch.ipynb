# %% [markdown]
# <a href="https://colab.research.google.com/github/bahawal-khan/LANGCHAIN-Practice/blob/main/AI%20Agent/AI_Agent_for_websearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qU langchain langchain-groq langchain-community ddgs
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 47.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.0/570.0 kB 36.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 105.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
import os
from getpass import getpass

os.environ["GROQ_API_KEY"] = getpass("Enter your Groq API Key: ")
# Out:
# Enter your Groq API Key: ··········

# %%
# !pip install -qU tavily-python langchain-tavily

# %%
import os
from getpass import getpass

os.environ["TAVILY_API_KEY"] = getpass("Enter your Tavily API Key: ")
# Out:
# Enter your Tavily API Key: ··········

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model = 'openai/gpt-oss-120b',temperature=0)

print('llm loaded successfully')
# Out:
# llm loaded successfully

# %%
from langchain_tavily import TavilySearch

search_tool = TavilySearch(
    max_results = 1
)
print('Tavily search tool loaded successfully')
# Out:
# Tavily search tool loaded successfully

# %%
from langchain.agents import create_agent

tools = [search_tool]

agent = create_agent(
    model=llm,
    tools=tools,
    system_prompt="""
    You are a helpful web-search AI agent.

    Use the Tavily search tool whenever the user asks for:
    - latest or current information
    - today's news
    - recent events
    - live or changing information

    When using Tavily, ALWAYS provide the user's search request
    in the required `query` parameter.

    Do not invent parameters such as cursor or id.

    For questions that do not require current information,
    answer directly without using the search tool.
    """
)

print("Agent loaded successfully!")
# Out:
# Agent loaded successfully!

# %%
while True:

    user_query = input("Enter your query: ")

    if user_query.lower() == "exit":
        print("Chat ended")
        break

    resp = agent.invoke({
        "messages": [
            {
                "role": "user",
                "content": user_query
            }
        ]
    })

    answer = resp["messages"][-1].content

    print("AI response:", answer)
    print()
# Out:
# Enter your query: hello
# AI response: Hello! How can I assist you today?
#
# Enter your query: What is news about pakistan today
# AI response: **Top Pakistan news today (27 Aug 2026)**
#
# | Topic | What happened | Key details |
# |-------|---------------|-------------|
# | **Hospital nursery fire in Islamabad** | A fast‑moving blaze ripped through the newborn‑care unit of a major government hospital, killing **14 infants**. | • The fire broke out on 26 Aug 2026; investigators appointed by Prime Minister Shehbaz Sharif visited the site on 27 Aug. <br>• Health Secretary Aslam Ghauri was dismissed by the prime minister in the wake of the tragedy. <br>• Families are demanding answers about the cause of the fire and whether the nursery had adequate fire‑prevention equipment. <br>• UNICEF expressed “deep sadness” and urged an urgent review of safety standards in Pakistani health facilities. <br>• The incident follows other recent child‑related disasters in Pakistan, such as the June collapse of a tutoring‑center roof in Lahore that killed 14 schoolchildren. <br>• Images of coffins and grieving parents have been widely circulated in the media.  (AP News)【8f04b1-00】 |
#
# **Why this story dominates today’s headlines**
# - The loss of newborns is one of the deadliest recent tragedies involving children in Pakistan.
# - The government’s swift dismissal of the health secretary signals political pressure to improve hospital safety.
# - International agencies (UNICEF) are calling for systemic reforms, putting the issue on both national and global agendas.
#
# *No other major Pakistan‑specific events were reported in today’s news feeds.*
#
# Enter your query: whats the condition in lords cricket ground and news ?
# AI response: **Current condition of the pitch at Lord’s (as of the latest reports – late August 2026)**
#
# | Aspect | What the reports say | Source |
# |--------|----------------------|--------|
# | **Colour/grass cover** | The surface is described as **“heavily green”** with a thick grass layer still visible across the playing area. | 【3†L0-L4】 |
# | **Moisture/pace** | The green‑covered wicket suggests a **damp, slower‑pace** pitch that will likely aid seam bowlers and make batting a little more challenging, especially early on. | (inferred from typical behaviour of green, grass‑rich pitches) |
# | **Timing** | This condition was noted **one day before the second Test** between Pakistan and England, meaning the ground staff have not yet had time to roll out the grass or dry the surface further. | 【3†L0-L4】 |
# | **Overall outlook** | Expect a **bowler‑friendly** surface with movement off the seam and possibly some swing, especially under overcast English conditions. | (standard analysis of green English pitches) |
#
# ---
#
# ### Recent news linked to Lord’s and the upcoming Test
#
# 1. **Pakistan captain Babar Azam’s fitness** – He announced he is “90 % fit” and will return for the second Test at Lord’s, despite a finger injury that kept him out of the first match. This adds a key batting figure back into the line‑up for Pakistan.
#    *Source: FOX Sports (AP) – “Babar Azam says he’s ‘90 %’ fit and set to return for Pakistan in 2nd test against England”*【2†L0-L9】
#
# 2. **Pitch commentary on social media** – A post on Instagram (and echoed on other cricket‑fan channels) highlighted the **still‑green pitch** at Lord’s, emphasizing that the surface looks “well‑covered with grass” just a day before play begins.
#    *Source: Instagram post titled “🚨 LORD’S PITCH STILL GREEN! 🌱🏏”*【4†L0-L4】
#
# ---
#
# ### What this means for the upcoming match
#
# - **Bowling advantage:** The green, grass‑rich surface will likely give England’s seam attack (e.g., James Anderson, Ollie Robinson) extra bounce and lateral movement. Pakistan’s bowlers will also benefit if they can exploit the seam.
# - **Batting challenge:** Batsmen on both sides should be prepared for the ball to swing early and for the pitch to stay a bit slower, especially in the first innings. Babar Azam’s return will be crucial for Pakistan’s top order.
# - **Ground‑staff plans:** With only a day left before the Test, there may be limited time for the curators to dry or roll the pitch, so the green condition is expected to persist into the early sessions.
#
# ---
#
# **Bottom line:** The Lord’s pitch is currently **very green and moist**, favouring seam and swing bowling, and the latest cricket news centres on Babar Azam’s near‑full fitness ahead of the second England‑Pakistan Test. Keep an eye on pre‑match briefings for any last‑minute changes to the surface.
#
# Enter your query: exit
# Chat ended
